# %%
d ={400.0: {'total_profit': -89645.0, 'num_days': 15, 'mean_daily_pnl': -5976.333333333333, 'std_daily_pnl': 589.030702397886, 'sharpe_ratio': -10.14604724168752, 'daily_returns': [-5854.0, -5827.5, -6978.5, -7672.5, -6020.5, -6356.0, -5374.0, -5717.5, -6964.0, -6427.0, -6613.5, -6343.5, -6788.0, -6708.5]}, 500.0: {'total_profit': -72252.5, 'num_days': 15, 'mean_daily_pnl': -4816.833333333333, 'std_daily_pnl': 694.331080418192, 'sharpe_ratio': -6.93737248580631, 'daily_returns': [-4624.0, -4469.0, -5580.0, -6727.0, -4898.5, -4967.0, -4003.0, -4339.0, -5795.0, -5215.0, -5297.5, -5050.5, -5237.5, -6049.5]}, 600.0: {'total_profit': -59934.5, 'num_days': 15, 'mean_daily_pnl': -3995.633333333333, 'std_daily_pnl': 741.6385927767773, 'sharpe_ratio': -5.387574719343068, 'daily_returns': [-3416.5, -3749.5, -4808.0, -6020.0, -3934.5, -3974.0, -3269.0, -3503.0, -4773.0, -4143.0, -4235.0, -4386.0, -4324.5, -5398.5]}, 700.0: {'total_profit': -49410.0, 'num_days': 15, 'mean_daily_pnl': -3294.0, 'std_daily_pnl': 743.8558499536077, 'sharpe_ratio': -4.428277333848269, 'daily_returns': [-2703.0, -3251.0, -3627.0, -5263.5, -3033.5, -3300.0, -2448.5, -2734.5, -3765.0, -3547.0, -3552.0, -3657.5, -3664.0, -4863.5]}, 800.0: {'total_profit': -41133.0, 'num_days': 15, 'mean_daily_pnl': -2742.2, 'std_daily_pnl': 619.4927319169767, 'sharpe_ratio': -4.4265248948352545, 'daily_returns': [-2661.0, -2852.0, -3022.5, -4412.0, -2616.5, -2699.5, -1897.5, -2200.5, -3298.0, -2886.5, -3133.5, -2761.5, -2718.5, -3973.5]}, 900.0: {'total_profit': -37393.5, 'num_days': 15, 'mean_daily_pnl': -2492.9, 'std_daily_pnl': 782.2313428420583, 'sharpe_ratio': -3.1869088637417917, 'daily_returns': [-2076.5, -2558.5, -2762.0, -4298.0, -1900.0, -2538.0, -1491.5, -1793.5, -3314.0, -2497.0, -2711.5, -2759.0, -2509.0, -4185.0]}, 1000.0: {'total_profit': -34011.0, 'num_days': 15, 'mean_daily_pnl': -2267.4, 'std_daily_pnl': 799.218310703193, 'sharpe_ratio': -2.8370220872505114, 'daily_returns': [-1765.5, -2237.5, -2443.5, -3586.0, -1733.5, -2162.5, -1162.5, -1466.0, -3695.0, -2297.5, -2549.5, -2566.5, -2372.5, -3973.0]}, 1100.0: {'total_profit': -30155.0, 'num_days': 15, 'mean_daily_pnl': -2010.3333333333333, 'std_daily_pnl': 817.8336334737135, 'sharpe_ratio': -2.458120149442287, 'daily_returns': [-1344.5, -2172.5, -1950.5, -3093.5, -1222.5, -2104.0, -1070.0, -1197.0, -3316.0, -1983.5, -2498.0, -2067.0, -2160.5, -3975.5]}, 1200.0: {'total_profit': -27701.5, 'num_days': 15, 'mean_daily_pnl': -1846.7666666666667, 'std_daily_pnl': 844.5392997525519, 'sharpe_ratio': -2.1867148955741493, 'daily_returns': [-1050.5, -1932.0, -1640.5, -2930.5, -1068.5, -1939.5, -739.5, -1147.5, -3345.0, -1725.0, -2315.5, -1970.0, -2201.0, -3696.5]}, 1300.0: {'total_profit': -24946.5, 'num_days': 15, 'mean_daily_pnl': -1663.1, 'std_daily_pnl': 806.1932854597637, 'sharpe_ratio': -2.0629048021053054, 'daily_returns': [-847.5, -1813.0, -1654.5, -2445.5, -882.5, -1720.5, -633.0, -980.0, -3214.5, -1554.0, -2101.0, -1610.0, -2074.0, -3416.5]}, 1400.0: {'total_profit': -22851.0, 'num_days': 15, 'mean_daily_pnl': -1523.4, 'std_daily_pnl': 850.0122628167052, 'sharpe_ratio': -1.792209438193132, 'daily_returns': [-496.5, -1403.0, -1642.5, -2455.0, -785.0, -1623.0, -468.5, -794.0, -2938.5, -1293.0, -1893.5, -1598.0, -2016.5, -3444.0]}, 1500.0: {'total_profit': -22010.0, 'num_days': 15, 'mean_daily_pnl': -1467.3333333333333, 'std_daily_pnl': 850.0283068515893, 'sharpe_ratio': -1.7262170230167668, 'daily_returns': [-759.5, -1393.0, -1719.0, -2455.5, -702.5, -1379.0, -418.5, -754.5, -2932.0, -1022.5, -1591.5, -1488.0, -1943.0, -3451.5]}, 1600.0: {'total_profit': -20217.0, 'num_days': 15, 'mean_daily_pnl': -1347.8, 'std_daily_pnl': 855.022741074822, 'sharpe_ratio': -1.5763323421149282, 'daily_returns': [-504.0, -1022.5, -1297.5, -2622.0, -921.0, -1285.0, -316.5, -605.0, -2676.5, -971.5, -1536.0, -1307.5, -1815.0, -3337.0]}, 1700.0: {'total_profit': -18861.0, 'num_days': 15, 'mean_daily_pnl': -1257.4, 'std_daily_pnl': 824.6783077203437, 'sharpe_ratio': -1.5247157445863078, 'daily_returns': [-463.5, -933.0, -1180.5, -2241.5, -906.5, -1150.0, -282.5, -585.0, -2725.5, -832.0, -1356.5, -1147.5, -1897.0, -3160.0]}, 1800.0: {'total_profit': -17567.0, 'num_days': 15, 'mean_daily_pnl': -1171.1333333333334, 'std_daily_pnl': 772.8222331698491, 'sharpe_ratio': -1.5153980864781156, 'daily_returns': [-412.5, -987.0, -900.0, -1522.5, -951.0, -1007.0, -292.0, -494.5, -2794.0, -900.5, -1512.5, -1154.5, -1654.0, -2985.0]}, 1900.0: {'total_profit': -15999.5, 'num_days': 15, 'mean_daily_pnl': -1066.6333333333334, 'std_daily_pnl': 771.3115362610544, 'sharpe_ratio': -1.3828826397487277, 'daily_returns': [-153.5, -815.5, -931.0, -1325.0, -737.5, -765.0, -331.0, -422.0, -2688.5, -823.5, -1323.0, -1264.0, -1553.0, -2867.0]}, 2000.0: {'total_profit': -13949.0, 'num_days': 15, 'mean_daily_pnl': -929.9333333333333, 'std_daily_pnl': 779.004021367106, 'sharpe_ratio': -1.1937465119902144, 'daily_returns': [155.5, -851.0, -718.5, -1011.5, -533.0, -722.0, -163.0, -391.5, -2533.0, -578.0, -1546.0, -1109.5, -1281.5, -2666.0]}, 2100.0: {'total_profit': -11997.5, 'num_days': 15, 'mean_daily_pnl': -799.8333333333334, 'std_daily_pnl': 774.5557128418319, 'sharpe_ratio': -1.0326349932902286, 'daily_returns': [222.5, -850.0, -472.0, -676.5, -250.0, -741.5, -78.0, -285.0, -2693.5, -538.5, -1416.5, -888.0, -1098.5, -2232.0]}, 2200.0: {'total_profit': -11601.0, 'num_days': 15, 'mean_daily_pnl': -773.4, 'std_daily_pnl': 730.5458191500045, 'sharpe_ratio': -1.058660497023796, 'daily_returns': [140.5, -932.0, -681.5, -871.0, -194.5, -562.0, -31.5, -213.5, -2534.5, -436.5, -1357.5, -708.5, -1143.0, -2075.5]}, 2300.0: {'total_profit': -10532.0, 'num_days': 15, 'mean_daily_pnl': -702.1333333333333, 'std_daily_pnl': 775.3243034435359, 'sharpe_ratio': -0.9055995410112502, 'daily_returns': [420.0, -1009.5, -470.0, -587.0, -251.5, -690.5, -67.0, -129.5, -2442.5, -272.0, -1107.5, -557.5, -1063.5, -2304.0]}, 2400.0: {'total_profit': -10701.5, 'num_days': 15, 'mean_daily_pnl': -713.4333333333333, 'std_daily_pnl': 807.0107579954608, 'sharpe_ratio': -0.8840443900716205, 'daily_returns': [496.0, -950.5, -486.0, -1040.5, -271.0, -669.0, 4.5, 49.0, -2383.5, -259.5, -1218.0, -570.0, -1009.0, -2394.0]}, 2500.0: {'total_profit': -10142.0, 'num_days': 15, 'mean_daily_pnl': -676.1333333333333, 'std_daily_pnl': 821.7576514734146, 'sharpe_ratio': -0.822789215434774, 'daily_returns': [713.0, -887.0, -743.0, -952.0, -273.5, -568.0, -48.0, -36.5, -2345.0, -192.5, -1063.5, -449.5, -828.5, -2468.0]}, 2600.0: {'total_profit': -9318.5, 'num_days': 15, 'mean_daily_pnl': -621.2333333333333, 'std_daily_pnl': 921.5939642537702, 'sharpe_ratio': -0.674085722595152, 'daily_returns': [925.5, -836.0, -634.0, -718.0, 14.0, -430.5, -67.5, -51.5, -2401.0, -121.0, -979.5, -254.0, -1006.0, -2759.0]}, 2700.0: {'total_profit': -8992.5, 'num_days': 15, 'mean_daily_pnl': -599.5, 'std_daily_pnl': 951.7233730588582, 'sharpe_ratio': -0.6299099265295911, 'daily_returns': [715.0, -677.0, -579.5, -893.0, -5.5, -193.0, 33.5, 40.5, -2238.5, -120.0, -850.0, -91.5, -1063.0, -3070.5]}, 2800.0: {'total_profit': -8096.5, 'num_days': 15, 'mean_daily_pnl': -539.7666666666667, 'std_daily_pnl': 940.9687183039247, 'sharpe_ratio': -0.5736287042991016, 'daily_returns': [669.5, -689.5, -595.5, -671.5, -101.0, -13.5, 109.5, 62.0, -2276.0, 58.5, -712.5, 25.5, -1037.0, -2925.0]}, 2900.0: {'total_profit': -7793.0, 'num_days': 15, 'mean_daily_pnl': -519.5333333333333, 'std_daily_pnl': 1044.5922209949995, 'sharpe_ratio': -0.49735516203487057, 'daily_returns': [425.0, -680.5, -586.5, -517.0, 149.0, 111.5, 275.5, 179.0, -2929.5, 130.0, -641.0, 130.0, -964.5, -2874.0]}, 3000.0: {'total_profit': -7847.5, 'num_days': 15, 'mean_daily_pnl': -523.1666666666666, 'std_daily_pnl': 1059.3521514904037, 'sharpe_ratio': -0.4938552925300835, 'daily_returns': [454.5, -621.5, -516.0, -886.5, 303.5, 95.5, 400.5, 142.5, -2742.0, 139.0, -765.0, 123.0, -952.0, -3023.0]}, 3100.0: {'total_profit': -7937.0, 'num_days': 15, 'mean_daily_pnl': -529.1333333333333, 'std_daily_pnl': 1104.8457852495405, 'sharpe_ratio': -0.4789205338859334, 'daily_returns': [646.5, -650.0, -702.5, -1057.0, 345.5, 29.5, 500.5, 246.0, -2858.0, 268.5, -652.5, -63.5, -976.0, -3014.0]}, 3200.0: {'total_profit': -7449.5, 'num_days': 15, 'mean_daily_pnl': -496.6333333333333, 'std_daily_pnl': 1057.8654751528702, 'sharpe_ratio': -0.46946738030330915, 'daily_returns': [427.0, -550.0, -623.0, -873.0, 586.5, 79.5, 456.0, 239.0, -2791.0, -54.5, -523.0, 8.0, -921.5, -2909.5]}, 3300.0: {'total_profit': -6502.5, 'num_days': 15, 'mean_daily_pnl': -433.5, 'std_daily_pnl': 1087.452239744114, 'sharpe_ratio': -0.3986381968388846, 'daily_returns': [697.5, -516.0, -668.5, -768.5, 691.0, 179.5, 357.0, 318.5, -2665.0, 25.0, -406.0, 133.0, -883.0, -2997.0]}, 3400.0: {'total_profit': -6495.5, 'num_days': 15, 'mean_daily_pnl': -433.03333333333336, 'std_daily_pnl': 1018.2528184571445, 'sharpe_ratio': -0.42527094006915195, 'daily_returns': [423.5, -565.0, -626.5, -826.5, 650.0, -77.5, 391.0, 484.5, -2544.5, 21.5, -459.5, 262.5, -866.0, -2763.0]}, 3500.0: {'total_profit': -6250.5, 'num_days': 15, 'mean_daily_pnl': -416.7, 'std_daily_pnl': 1029.3492129962108, 'sharpe_ratio': -0.40481888433865637, 'daily_returns': [16.5, -493.5, -551.5, -651.5, 726.0, 18.0, 361.5, 509.5, -2440.0, 29.5, -513.0, 304.5, -545.5, -3021.0]}, 3600.0: {'total_profit': -6118.5, 'num_days': 15, 'mean_daily_pnl': -407.9, 'std_daily_pnl': 1014.1858181440371, 'sharpe_ratio': -0.40219454137749444, 'daily_returns': [254.0, -414.0, -650.5, -497.0, 527.0, 93.0, 416.0, 623.0, -2398.0, -11.5, -396.0, 263.5, -1061.5, -2866.5]}, 3700.0: {'total_profit': -6579.5, 'num_days': 15, 'mean_daily_pnl': -438.6333333333333, 'std_daily_pnl': 1109.918842983668, 'sharpe_ratio': -0.3951940595532242, 'daily_returns': [263.0, -488.0, -588.0, -492.5, 644.0, 77.0, 478.5, 499.0, -2240.0, 35.0, -421.0, 268.0, -1160.5, -3454.0]}, 3800.0: {'total_profit': -6482.5, 'num_days': 15, 'mean_daily_pnl': -432.1666666666667, 'std_daily_pnl': 1079.8025855333417, 'sharpe_ratio': -0.4002274790379472, 'daily_returns': [109.5, -396.0, -508.5, -355.0, 653.0, -1.5, 312.5, 503.5, -2189.0, 47.5, -379.0, 272.5, -1131.0, -3421.0]}, 3900.0: {'total_profit': -6341.0, 'num_days': 15, 'mean_daily_pnl': -422.73333333333335, 'std_daily_pnl': 1149.0450671433782, 'sharpe_ratio': -0.3678996981243596, 'daily_returns': [322.0, -595.0, -529.0, -196.0, 637.0, 98.5, 383.0, 553.5, -2156.0, 44.0, -279.0, 289.5, -1267.5, -3646.0]}, 4000.0: {'total_profit': -6660.0, 'num_days': 15, 'mean_daily_pnl': -444.0, 'std_daily_pnl': 1139.1954196193174, 'sharpe_ratio': -0.38974875807380843, 'daily_returns': [455.0, -656.5, -557.5, -441.5, 579.0, 53.0, 376.0, 525.0, -2226.5, -51.5, -257.5, 314.5, -1175.5, -3596.0]}, 4100.0: {'total_profit': -5841.0, 'num_days': 15, 'mean_daily_pnl': -389.4, 'std_daily_pnl': 1168.7339718425128, 'sharpe_ratio': -0.3331810398102056, 'daily_returns': [775.5, -664.5, -590.5, -312.0, 629.0, 24.5, 322.5, 658.0, -2064.0, 15.5, -328.0, 414.5, -1047.0, -3674.5]}, 4200.0: {'total_profit': -5480.0, 'num_days': 15, 'mean_daily_pnl': -365.3333333333333, 'std_daily_pnl': 1163.894813870696, 'sharpe_ratio': -0.3138886168917326, 'daily_returns': [780.0, -506.5, -515.5, -515.5, 641.5, -99.5, 314.5, 683.0, -2042.5, 128.0, -315.5, 577.0, -984.5, -3624.5]}, 4300.0: {'total_profit': -5121.5, 'num_days': 15, 'mean_daily_pnl': -341.43333333333334, 'std_daily_pnl': 1186.7883522820086, 'sharpe_ratio': -0.28769521766607364, 'daily_returns': [967.5, -406.5, -573.5, -614.5, 525.5, -107.5, 373.5, 745.5, -1872.0, 253.0, -361.0, 573.5, -884.5, -3740.5]}, 4400.0: {'total_profit': -5071.0, 'num_days': 15, 'mean_daily_pnl': -338.06666666666666, 'std_daily_pnl': 1181.049468455397, 'sharpe_ratio': -0.28624259668716323, 'daily_returns': [814.0, -311.0, -606.5, -602.0, 600.5, -98.5, 423.5, 742.0, -1747.0, 257.5, -560.0, 623.5, -830.0, -3777.0]}, 4500.0: {'total_profit': -5177.5, 'num_days': 15, 'mean_daily_pnl': -345.1666666666667, 'std_daily_pnl': 1265.6508292904775, 'sharpe_ratio': -0.2727187141023459, 'daily_returns': [1180.0, -389.5, -556.5, -652.0, 750.5, -197.5, 378.0, 597.5, -1871.0, 345.0, -638.5, 645.0, -780.0, -3988.5]}, 4600.0: {'total_profit': -5515.5, 'num_days': 15, 'mean_daily_pnl': -367.7, 'std_daily_pnl': 1249.897230979493, 'sharpe_ratio': -0.2941841864165493, 'daily_returns': [1022.0, -402.0, -577.0, -722.5, 634.5, -210.0, 349.5, 594.0, -1821.0, 395.0, -737.5, 778.0, -855.0, -3963.5]}, 4700.0: {'total_profit': -5686.5, 'num_days': 15, 'mean_daily_pnl': -379.1, 'std_daily_pnl': 1286.6278822557667, 'sharpe_ratio': -0.2946461873151287, 'daily_returns': [898.0, -460.0, -560.0, -660.0, 576.5, -102.0, 387.0, 548.5, -1891.5, 283.5, -687.5, 890.5, -730.0, -4179.5]}, 4800.0: {'total_profit': -5831.5, 'num_days': 15, 'mean_daily_pnl': -388.76666666666665, 'std_daily_pnl': 1276.3531120272448, 'sharpe_ratio': -0.30459178028655765, 'daily_returns': [860.5, -526.0, -543.0, -597.5, 664.0, -118.0, 358.5, 540.5, -1837.0, 283.5, -907.0, 907.5, -800.5, -4117.0]}, 4900.0: {'total_profit': -5977.5, 'num_days': 15, 'mean_daily_pnl': -398.5, 'std_daily_pnl': 1319.6921781813596, 'sharpe_ratio': -0.3019643569829781, 'daily_returns': [1085.5, -496.5, -518.0, -868.0, 631.0, -18.0, 346.0, 520.0, -1903.0, 333.5, -894.5, 970.0, -1020.0, -4145.5]}, 5000.0: {'total_profit': -6149.5, 'num_days': 15, 'mean_daily_pnl': -409.96666666666664, 'std_daily_pnl': 1269.3684277455238, 'sharpe_ratio': -0.3229690117587, 'daily_returns': [727.5, -351.0, -543.0, -768.0, 573.0, -234.0, 325.5, 603.0, -1853.0, 350.5, -927.5, 966.5, -940.5, -4078.5]}}

# %%
d
# Out:
# {400.0: {'total_profit': -89645.0,
#   'num_days': 15,
#   'mean_daily_pnl': -5976.333333333333,
#   'std_daily_pnl': 589.030702397886,
#   'sharpe_ratio': -10.14604724168752,
#   'daily_returns': [-5854.0,
#    -5827.5,
#    -6978.5,
#    -7672.5,
#    -6020.5,
#    -6356.0,
#    -5374.0,
#    -5717.5,
#    -6964.0,
#    -6427.0,
#    -6613.5,
#    -6343.5,
#    -6788.0,
#    -6708.5]},
#  500.0: {'total_profit': -72252.5,
#   'num_days': 15,
#   'mean_daily_pnl': -4816.833333333333,
#   'std_daily_pnl': 694.331080418192,
#   'sharpe_ratio': -6.93737248580631,
#   'daily_returns': [-4624.0,
#    -4469.0,
#    -5580.0,
#    -6727.0,
#    -4898.5,
#    -4967.0,
#    -4003.0,
#    -4339.0,
#    -5795.0,
#    -5215.0,
#    -5297.5,
#    -5050.5,
#    -5237.5,
#    -6049.5]},
#  600.0: {'total_profit': -59934.5,
#   'num_days': 15,
#   'mean_daily_pnl': -3995.633333333333,
#   'std_daily_pnl': 741.6385927767773,
#   'sharpe_ratio': -5.387574719343068,
#   'daily_returns': [-3416.5,
# ...

# %%
# plot d.keys() vs d.values()['sharpe_ratio']

import matplotlib.pyplot as plt

plt.plot(d.keys(), [v['sharpe_ratio'] for v in d.values()])

# %%
plt.plot(d.keys(), [v['mean_daily_pnl'] for v in d.values()])

# %%
plt.plot(d.keys(), [v['std_daily_pnl'] for v in d.values()])

# %%
#plot mean vs std
plt.scatter([v['std_daily_pnl'] for v in d.values()], [v['mean_daily_pnl'] for v in d.values()])
plt.xlabel('std_daily_pnl')
plt.ylabel('mean_daily_pnl')
# Out:
# Text(0, 0.5, 'mean_daily_pnl')
